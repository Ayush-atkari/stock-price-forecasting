# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ---------------------------------------- 0.0/16.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/16.3 MB 1.9 MB/s eta 0:00:09
#    - -------------------------------------- 0.8/16.3 MB 1.6 MB/s eta 0:00:10
#    -- ------------------------------------- 1.0/16.3 MB 1.7 MB/s eta 0:00:10
#    --- ------------------------------------ 1.3/16.3 MB 1.5 MB/s eta 0:00:11
#    ---- ----------------------------------- 1.8/16.3 MB 1.6 MB/s eta 0:00:09
#    ----- ---------------------------------- 2.4/16.3 MB 1.9 MB/s eta 0:00:08
#    ------- -------------------------------- 2.9/16.3 MB 1.9 MB/s eta 0:00:08
#    --------- ------------------------------ 3.7/16.3 MB 2.2 MB/s eta 0:00:06
#    ---------- ----------------------------- 4.5/16.3 MB 2.3 MB/s eta 0:00:06
# ...

# %%
pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.10.3-cp310-cp310-win_amd64.whl.metadata (11 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 2.4 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.0/8.1 MB 2.6 MB/s eta 0:00:03
#    ------- -------------------------------- 1.6/8.1 MB 2.5 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.4/8.1 MB 2.8 MB/s eta 0:00:03
#    -------------- ------------------------- 2.9/8.1 MB 2.9 MB/s eta 0:00:02
#    ------------------ --------------------- 3.7/8.1 MB 2.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.5/8.1 MB 3.1 MB/s eta 0:00:02
#    -------------------------- ------------- 5.2/8.1 MB 3.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.1 MB 3.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.1/8.1 MB 3.4 MB/s eta 0:00:01
# ...

# %%
pip install yfinance
# Out:
# ...
#   Using cached yfinance-0.2.63-py2.py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached peewee-3.18.1.tar.gz (3.0 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached curl_cffi-0.11.4-cp39-abi3-win_amd64.whl.metadata (14 kB)
# ...
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# ...
# Using cached yfinance-0.2.63-py2.py3-none-any.whl (118 kB)
# ...
# Using cached curl_cffi-0.11.4-cp39-abi3-win_amd64.whl (1.6 MB)
# ...
# Using cached multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# ...
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# ...

# %%
import pandas as pd
import numpy as np
from matplotlib.pyplot import matplotlib as plt
import yfinance as yf
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### importing data
# import yfinance as yf
#
# # Define ticker symbol for Nifty 50
# nifty = yf.Ticker("^NSEI")
#
# # Download historical data
# data = nifty.history(period="5y")  # options: "1d", "5d", "1mo", "1y", etc.
#
# # Display data
# print(data.head())

# %% [markdown]
# data.describe

# %% [markdown]
# data.columns

# %% [markdown]
# data = nifty.history(start="2019-01-01", end="2024-01-01")

# %% [markdown]
# data.info

# %% [markdown]
# data['High'].plot(figsize=(12,4))

# %% [markdown]
# data.tail(5)

# %% [markdown]
# data['Close'].plot(figsize=(12,4))

# %% [markdown]
# data.reset_index(inplace=True)

# %% [markdown]
# data

# %%
data1 = pd.read_csv("nifty50.csv")

# %%
data1.head(5)
# Out:
#                         Date          Open  ...  Dividends  Stock Splits
# 0  2019-01-02 00:00:00+05:30  10868.849609  ...        0.0           0.0
# 1  2019-01-03 00:00:00+05:30  10796.799805  ...        0.0           0.0
# 2  2019-01-04 00:00:00+05:30  10699.700195  ...        0.0           0.0
# 3  2019-01-07 00:00:00+05:30  10804.849609  ...        0.0           0.0
# 4  2019-01-08 00:00:00+05:30  10786.250000  ...        0.0           0.0
#
# [5 rows x 8 columns]

# %%
data1.isnull
# Out:
# <bound method DataFrame.isnull of                            Date          Open  ...  Dividends  Stock Splits
# 0     2019-01-02 00:00:00+05:30  10868.849609  ...        0.0           0.0
# 1     2019-01-03 00:00:00+05:30  10796.799805  ...        0.0           0.0
# 2     2019-01-04 00:00:00+05:30  10699.700195  ...        0.0           0.0
# 3     2019-01-07 00:00:00+05:30  10804.849609  ...        0.0           0.0
# 4     2019-01-08 00:00:00+05:30  10786.250000  ...        0.0           0.0
# ...                         ...           ...  ...        ...           ...
# 1588  2025-06-13 00:00:00+05:30  24473.000000  ...        0.0           0.0
# 1589  2025-06-16 00:00:00+05:30  24732.349609  ...        0.0           0.0
# 1590  2025-06-17 00:00:00+05:30  24977.849609  ...        0.0           0.0
# 1591  2025-06-18 00:00:00+05:30  24788.349609  ...        0.0           0.0
# 1592  2025-06-19 00:00:00+05:30  24803.250000  ...        0.0           0.0
#
# [1593 rows x 8 columns]>

# %%
data1.Close
# Out:
# 0       10792.500000
# 1       10672.250000
# 2       10727.349609
# 3       10771.799805
# 4       10802.150391
#             ...
# 1588    24718.599609
# 1589    24946.500000
# 1590    24853.400391
# 1591    24812.050781
# 1592    24793.250000
# Name: Close, Length: 1593, dtype: float64

# %%
data1.plot()
# Out:
# <Axes: >

# %%
data1['Close'].plot(figsize=(12,4))
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 6))
plt.plot(data1['Date'], data1['Close'], label='NIFTY 50 Close Price', color='blue')
plt.title('NIFTY 50 Closing Price Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
data1['Date'] = pd.to_datetime(data1['Date'])
data1['Date'] = data1['Date'].dt.date

# %%
data1.Date
# Out:
# 0       2019-01-02
# 1       2019-01-03
# 2       2019-01-04
# 3       2019-01-07
# 4       2019-01-08
#            ...
# 1588    2025-06-13
# 1589    2025-06-16
# 1590    2025-06-17
# 1591    2025-06-18
# 1592    2025-06-19
# Name: Date, Length: 1593, dtype: object

# %%
data1.drop(columns=["Dividends","Stock Splits"])
# Out:
#             Date          Open  ...         Close  Volume
# 0     2019-01-02  10868.849609  ...  10792.500000  309700
# 1     2019-01-03  10796.799805  ...  10672.250000  286200
# 2     2019-01-04  10699.700195  ...  10727.349609  296600
# 3     2019-01-07  10804.849609  ...  10771.799805  269400
# 4     2019-01-08  10786.250000  ...  10802.150391  277700
# ...          ...           ...  ...           ...     ...
# 1588  2025-06-13  24473.000000  ...  24718.599609  318700
# 1589  2025-06-16  24732.349609  ...  24946.500000  305800
# 1590  2025-06-17  24977.849609  ...  24853.400391  242400
# 1591  2025-06-18  24788.349609  ...  24812.050781  237600
# 1592  2025-06-19  24803.250000  ...  24793.250000  274600
#
# [1593 rows x 6 columns]

# %%
import plotly.graph_objects as go
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import plotly.graph_objects as go
#
# ModuleNotFoundError: No module named 'plotly'

# %%
fig = go.Figure(data=[go.Candlestick(x=data1['Date'],
                                     open=data1['Open'],
                                     high=data1['High'],
                                     low=data1['Low'],
                                     close=data1['Close'])])

fig.update_layout(xaxis_rangeslider_visible=False,
                  title='NIFTY 50 Candlestick Chart',
                  xaxis_title='Date',
                  yaxis_title='Index Value')

fig.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(data1['Date'], data1['Close'], label='Nifty Closing Price', linewidth=1)
plt.title("Nifty 50 Closing Prices Over Time")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.legend()
plt.grid(True)
plt.show()

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
ma100 = data1.Close.rolling(100).mean()

# %%
ma100
# Out:
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#             ...
# 1588    23638.562441
# 1589    23654.909434
# 1590    23671.411445
# 1591    23686.084453
# 1592    23703.770449
# Name: Close, Length: 1593, dtype: float64

# %%
ma100.shape
# Out:
# (1593,)

# %%
ma100.isnull().sum()
# Out:
# np.int64(99)

# %%
ma200 = data1.Close.rolling(200).mean()

# %%
ma200.shape
# Out:
# (1593,)

# %%
ma200
# Out:
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#             ...
# 1588    24089.387480
# 1589    24090.004229
# 1590    24089.218232
# 1591    24088.189736
# 1592    24086.894238
# Name: Close, Length: 1593, dtype: float64

# %%
ma200.isnull().sum()
# Out:
# np.int64(199)

# %%
plt.figure(figsize=(12, 6))
plt.plot(data1.Close, label = f'Close Price', linewidth = 1)
plt.plot(ma100, label = f'Moving Average 100 Price', linewidth = 1)
plt.plot(ma200, label = f'Moving Average 200 Price', linewidth = 1)
plt.legend()
plt.show()

# %%
ma50 = data1.Close.rolling(50).mean()

# %%
plt.figure(figsize=(12, 6))
plt.plot(data1.Close, label = f'Close Price', linewidth = 1)
plt.plot(ma100, label = f'Moving Average 100 Price', linewidth = 1)
plt.plot(ma200, label = f'Moving Average 200 Price', linewidth = 1)
plt.plot(ma50, label = f'Moving Average 50 Price', linewidth = 1)
plt.legend()
plt.show()

# %%
ema100 = data1.Close.ewm(span=100, adjust = False).mean()
ema200 = data1['Close'].ewm(span=200, adjust = False).mean()
ema50 = data1['Close'].ewm(span=50, adjust = False).mean()

# %%
plt.figure(figsize=(12, 6))
plt.plot(data1.Close, label = f'Close Price', linewidth = 1)
plt.plot(ema100, label = f'Exp. Moving Average 100 Price', linewidth = 1)
plt.plot(ema200, label = f'Exp. Moving Average 200 Price', linewidth = 1)
plt.plot(ema50, label = f'Exp. Moving Average 50 Price', linewidth = 1)
plt.legend()
plt.show()

# %%
data_training = pd.DataFrame(data1['Close'][0:int(len(data1)*0.70)])
data_testing = pd.DataFrame(data1['Close'][int(len(data1)*0.70):int(len(data1))])

# %%
data_training.shape
# Out:
# (1115, 1)

# %%
data_testing.shape
# Out:
# (478, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

# %%
data_training_array = scaler.fit_transform(data_training)

# %%
plt.plot(data_training_array)

# %%
np.isnan(data_training_array).sum()
# Out:
# np.int64(0)

# %%
data_training_array
# Out:
# array([[0.26770728],
#        [0.25759123],
#        [0.26222649],
#        ...,
#        [1.        ],
#        [0.98607729],
#        [0.98810467]])

# %%
x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100:i])
    y_train.append(data_training_array[i, 0])

x_train, y_train  = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (1015, 100, 1)

# %%
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.models import Sequential

# %%
model = Sequential()

model.add(LSTM(units = 50, activation = 'relu', return_sequences = True, input_shape = (x_train.shape[1],1)))
model.add(Dropout(0.2))

model.add(LSTM(units = 60, activation = 'relu', return_sequences = True))
model.add(Dropout(0.3))

model.add(LSTM(units = 80, activation = 'relu', return_sequences = True))
model.add(Dropout(0.4))

model.add(LSTM(units = 120, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(units = 1))
# Out:
# c:\Users\ayush\OneDrive\Desktop\data-science_learning\stock price prediction\projenv\lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
from platform import python_version

print(python_version())
# Out:
# 3.10.18

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 100, 50)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 100, 60)        │        26,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 100, 60)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 100, 80)        │        45,120 │
# ...

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.fit(x_train, y_train, epochs = 50)
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 167ms/step - loss: 0.2241
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - loss: 0.0249
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 181ms/step - loss: 0.0183
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 182ms/step - loss: 0.0165
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 211ms/step - loss: 0.0128
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - loss: 0.0130
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 261ms/step - loss: 0.0118
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - loss: 0.0137
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 149ms/step - loss: 0.0109
# Epoch 10/50
# 19/32 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - loss: 0.0094

# %%
past_100_days = data_training.tail(100)

# %%
final_df = pd.concat([past_100_days, data_testing], ignore_index=True)

# %%
final_df.head()
# Out:
#           Close
# 0  17856.500000
# 1  17770.900391
# 2  17929.849609
# 3  18015.849609
# 4  18035.849609

# %%
input_data = scaler.fit_transform(final_df)

# %%
x_test = []
y_test = []

for i in range(100, input_data.shape[0]):
    x_test.append(input_data[i-100:i])
    y_test.append(input_data[i, 0])

x_test, y_test  = np.array(x_test), np.array(y_test)

# %%
x_test.shape
# Out:
# (478, 100, 1)

# %%
y_predicted = model.predict(x_test)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step

# %%
y_predicted.shape
# Out:
# (478, 1)

# %%
scaler.scale_
# Out:
# array([0.00010786])

# %%
scaler_factor = 1 / 0.0035166
y_predicted = y_predicted * scaler_factor
y_test = y_test * scaler_factor

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test, label = 'Original Price', linewidth = 1)
plt.plot(y_predicted, label = 'Predicted Price', linewidth = 1)
plt.legend()
plt.show()

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_predicted))
print("Final RMSE:", rmse)
